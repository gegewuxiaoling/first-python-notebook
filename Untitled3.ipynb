# %%
2+2
# Out:
# 4

# %%
3+3
# Out:
# 6

# %%
number=2
number+3
# Out:
# 5

# %%
number=2
number*3
# Out:
# 6

# %%
import pandas as pd
data=pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")
print data
# Out:
#   File "<ipython-input-5-5591434f2973>", line 3
#     print data
#              ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(data)?

# %%
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c25d78b78964> in <module>()
# ----> 1 print(data)
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
props=pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")
props.prop_name.value_counts()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
# ...

# %%
import pandas as pd
props=pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")
props.prop_name
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 9   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 10  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 11  PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# ...

# %%
import pandas as pd
my_list=[2,3,4,5]
my_series=pd.series(my_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-dd5410207c86> in <module>()
#       1 import pandas as pd
#       2 my_list=[2,3,4,5]
# ----> 3 my_series=pd.series(my_list)
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
import pandas as pd
my_list=[2,3,4,5]
my_series=pd.series(my_list)
print(my_series)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-53a498333436> in <module>()
#       1 import pandas as pd
#       2 my_list=[2,3,4,5]
# ----> 3 my_series=pd.series(my_list)
#       4 print(my_series)
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
import pandas as pd
my_list=[2,3,4,5]
my_series=pd.Series(my_list)
print(my_series)
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# dtype: int64

# %%
import pandas as pd
my_list=[2,3,4,5]
my_series=pd.Series(my_list)
print(my_series.sum())
# Out:
# 14

# %%
import pandas as pd
my_list=[2,3,4,5]
my_series=pd.Series(my_list)
print(my_series.max())
# Out:
# 5

# %%
import pandas as pd
my_list=[2,3,4,5]
my_series=pd.Series(my_list)
print(my_series.min())
# Out:
# 2

# %%
import pandas as pd
my_list=[2,3,4,5]
my_series=pd.Series(my_list)
print(my_series.mean())
# Out:
# 3.5

# %%
import pandas as pd
my_list=[2,3,4,5]
my_series=pd.Series(my_list)
print(my_series.describer())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-895f21b259fe> in <module>()
#       2 my_list=[2,3,4,5]
#       3 my_series=pd.Series(my_list)
# ----> 4 print(my_series.describer())
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'describer'

# %%
import pandas as pd
data=pd.read_csv("D:\360安全浏览器下载\committees.csv")
print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-0d072c446115> in <module>()
#       1 import pandas as pd
# ----> 2 data=pd.read_csv("D:\360安全浏览器下载\committees.csv")
#       3 print(data)
#
# ...

# %%
import pandas as pd
data=pd.read_csv("D:\committees.csv")
print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-6d8c2dc1698c> in <module>()
#       1 import pandas as pd
# ----> 2 data=pd.read_csv("D:\committees.csv")
#       3 print(data)
#
# ...

# %%
import pandas as pd
data=pd.read_csv("committees.csv")
print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-3e82e697ddc3> in <module>()
#       1 import pandas as pd
# ----> 2 data=pd.read_csv("committees.csv")
#       3 print(data)
#
# ...

# %%
import csv
filname="committees.csv"
data=[]
for datarow in data:
    print(datarow)

# %%
import csv
filname="committees.csv"
data=[]
print(data)
# Out:
# []

# %%
import csv
X=open("committees.csv","r")
reader=csv.reader(X)
data=[]
for item in reader:
    print(item)
    data.append(item)
print(data)
X.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-3acdff967513> in <module>()
#       1 import csv
# ----> 2 X=open("committees.csv","r")
#       3 reader=csv.reader(X)
#       4 data=[]
#       5 for item in reader:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'committees.csv'

# %%
import pandas as pd
data=pd.read_csv("D:\360安全浏览器下载\committees.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-0085e28f2253> in <module>()
#       1 import pandas as pd
# ----> 2 data=pd.read_csv("D:\360安全浏览器下载\committees.csv")
#
# ...

# %%
import pandas as pd
data=pd.read_csv("D:/360安全浏览器下载/committees.csv")
print(data)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-26-2bbc732fb276> in <module>()
#       1 import pandas as pd
# ----> 2 data=pd.read_csv("D:/360安全浏览器下载/committees.csv")
#       3 print(data)
#
# ...

# %%
data
# Out:
# []

# %%
data.describe
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-557c822c1a35> in <module>()
# ----> 1 data.describe
#
# AttributeError: 'list' object has no attribute 'describe'

# %%
import pandas as pd
i=pd.read_csv("D:/360安全浏览器下载/committees.csv")
i.describe()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-30-9e036adc0826> in <module>()
#       1 import pandas as pd
# ----> 2 i=pd.read_csv("D:/360安全浏览器下载/committees.csv")
#       3 i.describe()
#
# ...

# %%
import pandas as pd
df=pd.Dataframe([[4,2,3,3],[2,4,5,2]])
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-355446112427> in <module>()
#       1 import pandas as pd
# ----> 2 df=pd.Dataframe([[4,2,3,3],[2,4,5,2]])
#       3 print(df)
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
import pandas as pd
df=pd.DataFrame(data=list([[4,2,3,3],[2,4,5,2],[3,4,3,3]]))
print(df)
# Out:
#    0  1  2  3
# 0  4  2  3  3
# 1  2  4  5  2
# 2  3  4  3  3

# %%
import pandas as pd
pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 7    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 8    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 9    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 10   ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 11   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# ...

# %%
props=pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.5+ KB

# %%
import pandas as pd
pd.read_csv("C:\shuju\committees.csv")
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 7    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 8    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 9    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 10   ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 11   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# ...

# %%
import pandas as pd
contribs=pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")
contribs.head()
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
props.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-0b0ef796a747> in <module>()
# ----> 1 props.head()
#
# NameError: name 'props' is not defined

# %%
import pandas as pd
pd.read_csv("D:/360安全浏览器下载/committees.csv","w")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-42-1205bd4cb7be> in <module>()
#       1 import pandas as pd
# ----> 2 pd.read_csv("D:/360安全浏览器下载/committees.csv","w")
#
# ...
